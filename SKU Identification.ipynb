# %%
import numpy as np
import pandas as pd

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
rules=pd.read_csv('rules_train1.csv')

# %%
rules.shape
# Out:
# (89428, 10)

# %%
sku=pd.read_csv('SKU_BRANDS.csv',low_memory=False)

# %%
sku.head()
# Out:
#    SKU      BRAND
# 0    3   TURNBURY
# 1    4  C A SPOR
# 2    5  BEAU IDE
# 3    8  HARTSTRI
# 4   15  JONES/LA

# %%
rules[10000:10050]
# Out:
#                                              antecedents  \
# 10000  frozenset({'SKU:_839811', 'SKU:_1228402', 'SKU...
# 10001  frozenset({'SKU:_839811', 'SKU:_7337472', 'SKU...
# 10002  frozenset({'SKU:_1228402', 'SKU:_7337472', 'SK...
# 10003  frozenset({'SKU:_839811', 'SKU:_1228402', 'SKU...
# 10004         frozenset({'SKU:_839811', 'SKU:_7337472'})
# 10005        frozenset({'SKU:_1228402', 'SKU:_7337472'})
# 10006        frozenset({'SKU:_7337472', 'SKU:_1577472'})
# 10007         frozenset({'SKU:_839811', 'SKU:_1228402'})
# 10008         frozenset({'SKU:_839811', 'SKU:_1577472'})
# 10009        frozenset({'SKU:_1228402', 'SKU:_1577472'})
# 10010                        frozenset({'SKU:_7337472'})
# 10011                         frozenset({'SKU:_839811'})
# 10012                        frozenset({'SKU:_1228402'})
# 10013                        frozenset({'SKU:_1577472'})
# 10014  frozenset({'SKU:_839811', 'SKU:_8214333', 'SKU...
# ...

# %%
sku[sku['SKU'].isin([9633,9932313])]
# Out:
#        SKU      BRAND
# 1451  9633  CLINIQUE

# %%
sku[sku['SKU'].isin([26691,2966979])]
# Out:
#             SKU      BRAND
# 4074      26691  AUGUST H
# 463199  2966979  AUGUST H

# %%
sku[sku['SKU'].isin([4380542,44522])]
# Out:
#             SKU      BRAND
# 7027      44522  KASPER A
# 685781  4380542  NYGARD

# %%
sku[sku['SKU'].isin([1724045,64045])]
# Out:
#             SKU      BRAND
# 10135     64045  KORET OF
# 269323  1724045  KORET OF

# %%
sku[sku['SKU'].isin([957390,78355])]
# Out:
#            SKU      BRAND
# 12194    78355  LANCOME
# 149422  957390  G. H. BA

# %%
sku[sku['SKU'].isin([112212,4313732])]
# Out:
#             SKU      BRAND
# 17678    112212  CABERNET
# 675106  4313732  CABERNET

# %%
sku[sku['SKU'].isin([3437218,122118])]
# Out:
#             SKU      BRAND
# 19195    122118  LIZ CLAI
# 536929  3437218  BIJOUX G

# %%
sku[sku['SKU'].isin([186170,126170])]
# Out:
#           SKU      BRAND
# 19584  126170  LIZ CLAI
# 28820  186170  LIZ CLAI

# %%
sku[sku['SKU'].isin([708367,126170])]
# Out:
#            SKU      BRAND
# 19584   126170  LIZ CLAI
# 110637  708367  L.SCOTT

# %%
sku[sku['SKU'].isin([1937918,126170])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 301654  1937918  M.M. & R

# %%
sku[sku['SKU'].isin([126170,5378213])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 842616  5378213  NEXT ERA

# %%
sku[sku['SKU'].isin([126170,5706016])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 893911  5706016  IT JEANS

# %%
sku[sku['SKU'].isin([126170,5888065])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 922810  5888065  LIZ CLAI

# %%
sku[sku['SKU'].isin([6163107,126170])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 966167  6163107  CALVIN K

# %%
sku[sku['SKU'].isin([7044853,126170])]
# Out:
#           SKU      BRAND
# 19584  126170  LIZ CLAI

# %%
sku[sku['SKU'].isin([146997,2598084])]
# Out:
#             SKU      BRAND
# 22815    146997  ROUNDTRE
# 405334  2598084  ROUNDTRE

# %%
sku[sku['SKU'].isin([6416562,148061])]
# Out:
#              SKU      BRAND
# 23014     148061  FORCE ON
# 1005150  6416562  FORCE ON

# %%
sku[sku['SKU'].isin([148061,7546562])]
# Out:
#           SKU      BRAND
# 23014  148061  FORCE ON

# %%
sku[sku['SKU'].isin([160720,5367556])]
# Out:
#             SKU      BRAND
# 25101    160720  NAPIER/V
# 840888  5367556  LIZ CLAI

# %%
sku[sku['SKU'].isin([6036119,176017])]
# Out:
#             SKU      BRAND
# 27276    176017  CABERNET
# 946200  6036119  CABERNET

# %%
sku[sku['SKU'].isin([708367,186170])]
# Out:
#            SKU      BRAND
# 28820   186170  LIZ CLAI
# 110637  708367  L.SCOTT

# %%
sku[sku['SKU'].isin([5378213,86170])]
# Out:
#             SKU      BRAND
# 842616  5378213  NEXT ERA

# %%
sku[sku['SKU'].isin([5706016,186170])]
# Out:
#             SKU      BRAND
# 28820    186170  LIZ CLAI
# 893911  5706016  IT JEANS

# %%
sku[sku['SKU'].isin([186170,5888065])]
# Out:
#             SKU      BRAND
# 28820    186170  LIZ CLAI
# 922810  5888065  LIZ CLAI

# %%
sku[sku['SKU'].isin([4008011, 1842285, 9633])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 287326  1842285  CLINIQUE
# 626648  4008011  CLINIQUE

# %%
sku[sku['SKU'].isin([9633, 4008011, 1842285])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 287326  1842285  CLINIQUE
# 626648  4008011  CLINIQUE

# %%
sku[sku['SKU'].isin([4108011, 1842285, 9633])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 287326  1842285  CLINIQUE
# 642444  4108011  CLINIQUE

# %%
sku[sku['SKU'].isin([9633, 4108011, 1842285])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 287326  1842285  CLINIQUE
# 642444  4108011  CLINIQUE

# %%
sku[sku['SKU'].isin([9633, 1842285, 9323130])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 287326  1842285  CLINIQUE

# %%
sku[sku['SKU'].isin([9323130, 1842285, 9633])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 287326  1842285  CLINIQUE

# %%
sku[sku['SKU'].isin([4008011, 4108011, 9633])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 626648  4008011  CLINIQUE
# 642444  4108011  CLINIQUE

# %%
sku[sku['SKU'].isin([4008011, 9633, 9323130])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 626648  4008011  CLINIQUE

# %%
sku[sku['SKU'].isin([126170, 186170, 5706016])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 28820    186170  LIZ CLAI
# 893911  5706016  IT JEANS

# %%
sku[sku['SKU'].isin([5706016, 186170, 126170])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 28820    186170  LIZ CLAI
# 893911  5706016  IT JEANS

# %%
sku[sku['SKU'].isin([186170, 5706016, 126170])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 28820    186170  LIZ CLAI
# 893911  5706016  IT JEANS

# %%
sku[sku['SKU'].isin([5378213, 186170, 126170])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 28820    186170  LIZ CLAI
# 842616  5378213  NEXT ERA

# %%
sku[sku['SKU'].isin([708367, 186170, 126170])]
# Out:
#            SKU      BRAND
# 19584   126170  LIZ CLAI
# 28820   186170  LIZ CLAI
# 110637  708367  L.SCOTT

# %%
sku[sku['SKU'].isin([126170, 1937918, 186170])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 28820    186170  LIZ CLAI
# 301654  1937918  M.M. & R

# %%
sku[sku['SKU'].isin([126170, 708367, 186170])]
# Out:
#            SKU      BRAND
# 19584   126170  LIZ CLAI
# 28820   186170  LIZ CLAI
# 110637  708367  L.SCOTT

# %%
sku[sku['SKU'].isin([9323130, 9633, 4108011])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 642444  4108011  CLINIQUE

# %%
sku[sku['SKU'].isin([4008011, 9633, 9323130])]
# Out:
#             SKU      BRAND
# 1451       9633  CLINIQUE
# 626648  4008011  CLINIQUE

# %%
4008011, 1842285, 9633,9633, 4008011, 1842285,4108011, 1842285, 9633,9633, 1842285, 9323130,9323130, 1842285, 9633,4008011, 4108011, 9633,9633, 4008011, 4108011,4008011, 9633, 9323130,126170, 186170, 5706016,5706016, 186170, 126170,186170, 5706016, 126170,126170, 1937918, 186170,9323130, 9633, 4108011,4008011, 9633, 9323130

# %%
sku[sku['SKU'].isin([5378213, 5888065, 126170, 1937918, 186170, 5706016, 708367,5378213, 5888065, 126170, 1937918, 186170, 708367, 5706016,5378213, 5888065, 126170, 1937918, 5706016, 708367, 186170,5378213, 5888065, 126170, 186170, 5706016, 708367, 1937918,5378213, 5888065, 1937918, 186170, 5706016, 708367, 126170,5378213, 126170, 1937918, 186170, 5706016, 708367, 5888065,5888065, 126170, 1937918, 186170, 5706016, 708367, 5378213,5378213, 5888065, 126170, 1937918, 186170, 5706016, 708367,5378213, 5888065, 126170, 1937918, 5706016, 186170, 708367,5378213, 5888065, 126170, 1937918, 708367, 186170, 5706016,5378213, 5888065, 126170, 186170, 5706016, 1937918, 708367,5378213, 5888065, 126170, 186170, 708367, 1937918, 5706016])]
# Out:
#             SKU      BRAND
# 19584    126170  LIZ CLAI
# 28820    186170  LIZ CLAI
# 110637   708367  L.SCOTT
# 301654  1937918  M.M. & R
# 842616  5378213  NEXT ERA
# 893911  5706016  IT JEANS
# 922810  5888065  LIZ CLAI

# %%
sku[sku['SKU'].isin([5378213, 126170, 6163107, 186170, 5706016, 1937918, 708367])]
# Out:
# %%
sku_best_by3.drop_duplicates()
# Out:
#         SKU
# 0   4008011
# 1   1842285
# 2      9633
# 6   4108011
# 11  9323130
# 24   126170
# 25   186170
# 26  5706016
# 34  1937918
# 45  5378213
# 51   708367

# %%
sku_best_by7=pd.DataFrame(np.array([1937918, 126170, 5888065, 708367, 186170, 5706016, 6163107,6163107, 9186625, 708367, 1937918, 186170, 126170, 5378213,5378213, 5888065, 126170, 1937918, 708367, 186170, 9186625,1937918, 7044853, 5888065, 708367, 186170, 126170, 5378213,1937918, 5378213, 5888065, 708367, 186170, 126170, 6163107,5706016, 5378213, 708367, 1937918, 186170, 126170, 9186625,7044853, 5378213, 1937918, 186170, 708367, 5706016, 126170,126170, 6163107, 1937918, 186170, 5706016, 5378213, 708367,5378213, 126170, 6163107, 186170, 5706016, 1937918, 708367,5378213, 5888065, 126170, 1937918, 186170, 5706016, 708367,5378213, 5888065, 126170, 1937918, 186170, 708367, 5706016,5378213, 5888065, 126170, 1937918, 5706016, 708367, 186170,5378213, 5888065, 126170, 186170, 5706016, 708367, 1937918,5378213, 5888065, 1937918, 186170, 5706016, 708367, 126170,5378213, 126170, 1937918, 186170, 5706016, 708367, 5888065,5888065, 126170, 1937918, 186170, 5706016, 708367, 5378213,5378213, 5888065, 126170, 1937918, 186170, 5706016, 708367,5378213, 5888065, 126170, 1937918, 5706016, 186170, 708367,5378213, 5888065, 126170, 1937918, 708367, 186170, 5706016,5378213, 5888065, 126170, 186170, 5706016, 1937918, 708367,5378213, 5888065, 126170, 186170, 708367, 1937918, 5706016]),columns=['SKU'])

# %%
sku_best_by7.drop_duplicates()
# Out:
#         SKU
# 0   1937918
# 1    126170
# 2   5888065
# 3    708367
# 4    186170
# 5   5706016
# 6   6163107
# 8   9186625
# 13  5378213
# 22  7044853

# %%
frames = [sku_best_by2,sku_best_by3,sku_best_by7]

# %%
 result = pd.concat(frames)

# %%
result=result.drop_duplicates()

# %%
len(result)
# Out:
# 100

# %%
result.reset_index(drop=True)
# Out:
#         SKU
# 0   5888065
# 1    126170
# 2   6163107
# 3   7044853
# 4    146997
# ..      ...
# 95  4008011
# 96  1842285
# 97  4108011
# 98  9323130
# 99  9186625
#
# [100 rows x 1 columns]

# %%
Brands=sku[sku['SKU'].isin([5888065,126170,6163107,7044853,146997,2598084,6416562,148061,8226562,8976562,160720,5367556,6036119,176017,186170,708367,5706016,656698,264286,1754130,7376697,8836697,264715,3254117,314088,8077274,316667,3237302,324286,1576017,346017,346689,1276689,3528835,3638835,9469364,354814,9600684,7176700,7446105,8686732,5766710,407541,1394179,416740,2376291,466823,2626299,3406291,4751496,474515,3896862,486689,756689,7497591,4432751,423714,7256846,458020,9744811,366117,9896116,3924024,5317384,293277,6536659,2779816,309665,204684,2161039,4594108,231057,9411343,250896,1937918,5378213,7546562,7886562,4380542,44522,957390,78355,3437218,122118,7083675378213,9633,9932313,26691,2966979,1724045,64045,112212,4313732,86170,4008011,1842285,4108011,9323130,9186625])]

# %%
export_csv = result.to_csv ('FINALSKU.csv', index = None, header=True)

# %%
export_csv = Brands.to_csv ('FINALBRANDS.csv', index = None, header=True)
